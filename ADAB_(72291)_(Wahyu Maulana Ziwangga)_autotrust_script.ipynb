# %%
import pandas as pd 
import numpy as np
import requests
import re
import time # For time-related functions
import math # For more advanced math operations


from bs4 import BeautifulSoup
from fake_useragent import UserAgent # For 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By

# %%
# Define main_url for listing page, and base_url for later detail page
main_url = 'https://toyotatrust.astra.co.id/stock'

# %%
# Set useragent as random fake user-agent
ua = UserAgent()
userAgent = ua.random

# Set the options for chromedriver
options = Options()

# options.add_argument('--headless') # If headless is enabled, the browser won't show up
options.add_argument('--disable-gpu') # Also used for headless
options.add_argument('--disable-extensions') # Disable any extensions
options.add_argument("--disable-notifications") # Disable notifications
options.add_argument("--disable-popup-blocking") # Disable pop-up
options.add_argument('--blink-settings=imagesEnabled=false') # Disable loading image for faster and more efficient page load
options.add_argument(f'--user-agent={userAgent}') # For choosing user-agent profile
options.add_argument('--incognito') # Enable incognito mode

# Set chromedriver as selenium webdriver and set timeout limit as 10 seconds
driver = webdriver.Chrome(options=options)
driver.set_page_load_timeout(10)
driver.get(main_url)
print("Open PLP page 1")
time.sleep(10)
# Out:
# Open PLP page 1

# %%
req = requests.get(main_url, headers={'User-Agent': ua.random}, timeout=10)

# %%
#Create function to collect PDP URL
def collector_URL():
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    # Loop by using the result of .find_all() function and find the "href" attribute from each elements
    for link in soup.find_all("div", {"class": "MuiPaper-root MuiPaper-elevation MuiPaper-rounded MuiPaper-elevation1 MuiCard-root css-o64p2b"}):
        car_link.append("https://toyotatrust.astra.co.id" + link.find("a").get("href"))
    # Let's check the result
    print(f"Total link: {len(car_link)}")
    return car_link

# %%
# Create an empty list for collect PDP URL

car_link = []

#Panggil function collector_URL() untuk mengumpulkan link URL PDP dari halaman PLP yg dibuka dan masukkan ke list car_link

#Collect PLP page 1
collector_URL()
print("Collect link URL PDP from PLP page 1 ")
# Out:
# Total link: 20
# Collect link URL PDP from PLP page 1

# %%
time.sleep(10)

# %%
jumlah_page=8
for i in range(2,jumlah_page+1):
    driver.find_element(By.XPATH,'//*[@id="__next"]/div/div[3]/nav/ul/li[10]/button').click() #pindah page
    print("Open PLP page ",+i)
    time.sleep(10)
    collector_URL() #collect URL
    print("Collect link URL PDP from PLP page ",+i)
    time.sleep(10)
# Out:
# Open PLP page  2
# Total link: 40
# Collect link URL PDP from PLP page  2
# Open PLP page  3
# Total link: 60
# Collect link URL PDP from PLP page  3
# Open PLP page  4
# Total link: 80
# Collect link URL PDP from PLP page  4
# Open PLP page  5
# Total link: 100
# Collect link URL PDP from PLP page  5
# Open PLP page  6
# Total link: 120
# Collect link URL PDP from PLP page  6
# Open PLP page  7
# Total link: 140
# Collect link URL PDP from PLP page  7
# Open PLP page  8
# Total link: 146
# Collect link URL PDP from PLP page  8

# %%
car_link
# Out:
# ['https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2021-4638',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2020-3828',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2019-4241',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-CVT-GR-SPORT-AT-2021-4228',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-CVT-GR-SPORT-AT-2021-4058',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-TRD-(ALL-NEW)-AT-2020-4260',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-TRD-(ALL-NEW)-AT-2020-3907',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-LIMITED-(NEW)-AT-2012-3474',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-LIMITED-(NEW)-AT-2012-4421',
#  'https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-E-MT-(NEW)-MT-2013-4326',
#  'https://toyotatrust.astra.co.id/TOYOTA-VOXY-2.0-AT-AT-2017-3067',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-MT-TRD-BENSIN-(NEW)-MT-2017-4720',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-MT-TRD-BENSIN-(ALL-NEW)-MT-2021-4531',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-MT-TRD-BENSIN-(ALL-NEW)-MT-2021-4267',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-MT-TRD-BENSIN-(ALL-NEW)-MT-2020-4271',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-MT-TRD-BENSIN-(ALL-NEW)-MT-2019-4803',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-AT-TRD-BENSIN-(ALL-NEW)-AT-2020-4782',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-AT-TRD-BENSIN-(ALL-NEW)-AT-2019-3673',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-AT-TRD-BENSIN-(ALL-NEW)-AT-2019-3867',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-AT-TRD-BENSIN-(ALL-NEW)-AT-2019-4272',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S-AT-TRD-BENSIN-(ALL-NEW)-AT-2019-4738',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-G-MT-MT-2022-4533',
#  'https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-AT-GR-SPORT-AT-2021-4069',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.5-V-MT-DIESEL-(OLD)-MT-2008-4507',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-VENTURER-AT-DIESEL-(REBORN)-AT-2019-4005',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-VENTURER-AT-DIESEL-(REBORN)-AT-2019-3647',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-VENTURER-AT-DIESEL-(REBORN)-AT-2019-4376',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-VENTURER-AT-DIESEL-(REBORN)-AT-2019-4547',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-VENTURER-AT-DIESEL-(REBORN)-AT-2019-3958',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-V-AT-DIESEL-(REBORN)-AT-2020-3606',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-V-AT-DIESEL-(REBORN)-AT-2020-4062',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-V-AT-DIESEL-(REBORN)-AT-2019-4752',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-V-AT-DIESEL-(REBORN)-AT-2019-4478',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.4-V-AT-DIESEL-(REBORN)-AT-2019-4106',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.0-V-AT-BENSIN-(REBORN)-AT-2018-4352',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.0-V-AT-BENSIN-(REBORN)-AT-2018-4401',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.0-V-AT-BENSIN-(OLD)-AT-2010-4699',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.0-G-AT-BENSIN-(REBORN)-AT-2017-4599',
#  'https://toyotatrust.astra.co.id/TOYOTA-INNOVA-INNOVA-2.0-E-MT-BENSIN-MT-2006-4450',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.5-G-AT-VNT-TRD-DIESEL-AT-2015-2958',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.5-G-AT-VNT-TRD-DIESEL-AT-2014-4380',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.5-G-AT-DIESEL-(OLD)-AT-2010-4287',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-TRD-AT-DIESEL-(NEW)-AT-2021-4302',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-TRD-AT-DIESEL-(NEW)-AT-2020-4620',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-TRD-AT-DIESEL-(NEW)-AT-2020-4395',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-TRD-AT-DIESEL-(NEW)-AT-2020-3913',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-AT-DIESEL-(NEW)-AT-2020-4183',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ-AT-DIESEL-(NEW)-AT-2019-4056',
#  'https://toyotatrust.astra.co.id/TOYOTA-FORTUNER-FORTUNER-2.4-VRZ
#  'https://toyotatrust.astra.co.id/HONDA-HRV-HRV-1.5-S-A/T-AT-2017-4182',
#  'https://toyotatrust.astra.co.id/HONDA-HRV-HRV-1.5-E-A/T-AT-2021-4129',
#  'https://toyotatrust.astra.co.id/HONDA-HRV-HRV-1.5-E-A/T-AT-2020-2993',
#  'https://toyotatrust.astra.co.id/HONDA-HRV-HRV-1.5-E-A/T-AT-2016-4193',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.4-AT-(NEW)-AT-2016-4308',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.4-AT-(NEW)-AT-2016-4368',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.4-AT-(ALL-NEW)-AT-2012-3232',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.0-AT-(ALL-NEW)-AT-2014-4306',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-ALL-NEW-CRV-2.0-AT-AT-2017-2987',
#  'https://toyotatrust.astra.co.id/HONDA-CRV-ALL-NEW-CRV-1.5-TURBO-PRESTIGE-AT-AT-2018-4584',
#  'https://toyotatrust.astra.co.id/HONDA-CITY-CITY--IVTEC-1.5-E-CVT-(ALL-NEW)-AT-2019-4249',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-4341',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-3629',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-4253',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-PRESTIGE-AT-2017-4670',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-AT-2019-4201',
#  'https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-AT-2016-4511',
#  'https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-SATYA-E-1.2-MT-MT-2017-4786',
#  'https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-SATYA-E-1.2-MT-(ALL-NEW)-MT-2019-4314',
#  'https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-MT-MT-2016-4060',
#  'https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-MT-MT-2016-4157',
#  'https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-CVT-AT-2016-4435',
#  'https://toyotatrust.astra.co.id/DAIHATSU-XENIA-ALL-NEW-XENIA-1.3-X-MT-MT-2013-4689',
#  'https://toyotatrust.astra.co.id/DAIHATSU-AYLA-NEW-AYLA-1.2-R-AT-AT-2018-4783']

# %%
len(car_link)
# Out:
# 146

# %%
# Create empty lists for each feature
product_link = []
product_name = []
product_model = []
product_type = []
product_price = []
product_police_n = []
product_police_n_t= []
product_mileage= []
production_year= []
product_post_location= []
product_color= []
product_fuel_type= []
product_transmission= []

# %%
#create scrapping automation script to collect data from each PDP URL
for pdp in car_link:
    # Assign another req and soup variables for PDP
    print(pdp)
    pdp_req = requests.get(pdp)
    pdp_soup = BeautifulSoup(pdp_req.text, "html.parser")
    
    price = pdp_soup.find_all("h6", {"class": "MuiTypography-root MuiTypography-h6 css-1lnycu1"})
    spek = pdp_soup.find_all("div", {"class": "MuiGrid-root MuiGrid-container MuiGrid-spacing-xs-2 css-19g4pw0"})
    location= pdp_soup.find_all("h6", {"class": "MuiTypography-root MuiTypography-subtitle2 css-3pkvrl"})
    
    # Product_link
    product_link.append(pdp)
    
    
    # Product_Name
    try:
        pn1=pdp.split("/")[-1].split("-")
        pn2=""
        for i in range(0,len(pn1)-1):
            pn2=pn2+" "+pn1[i]
        product_name.append(pn2.strip())
        
    except Exception:
         product_name.append(None)
     
    
    # Product_Model
    try:
        product_model.append(spek[0].find_all('p')[1].get_text())
        
    except Exception:
         product_model.append(None)
            
            
     # Product_Type
    try:
        product_type.append(spek[0].find_all('p')[13].get_text())
        
    except Exception:
         product_type.append(None)
            
            
    #Product_Price
    try:
        product_price.append(price[0].get_text())
        
    except Exception:
        product_price.append(None)
        
        
    #Product_Police_Number
    try:
        product_police_n.append(spek[0].find_all('p')[7].get_text())
        
    except Exception:
        product_police_n.append(None)
        
    #Product_Police_Number_Type
    try:
        plat=spek[0].find_all('p')[7].get_text()
        num = re.findall(r'\d+', plat)
        if int(num[0])%2==0:
             product_police_n_t.append("even")
        else:
             product_police_n_t.append("odd")     
        
    except Exception:
         product_police_n_t.append(None)
    
    
    # product_mileage    
    try:
        product_mileage.append(spek[0].find_all('p')[3].get_text())
        
    except Exception:
         product_mileage.append(None)
    
    # production_year   
    try:
        production_year.append(spek[0].find_all('p')[5].get_text())
        
    except Exception:
        production_year.append(None)
        
        
    # product_post_location   
    try:        
        product_post_location.append(location[1].get_text().split(" ")[-1])
        
    except Exception:
        product_post_location.append(None)
        
    
    # product_color    
    try:
        product_color.append(spek[0].find_all('p')[9].get_text())
        
    except Exception:
         product_color.append(None)
            
            
    # product_fuel_type   
    try:
        product_fuel_type.append(spek[0].find_all('p')[15].get_text())
        
    except Exception:
         product_fuel_type.append(None)
    
    
    # product_transmission    
    try:
        product_transmission.append(spek[0].find_all('p')[11].get_text())
        
    except Exception:
         product_transmission.append(None)
# Out:
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2021-4638
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2020-3828
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-MT-TRD-(ALL-NEW)-MT-2019-4241
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-CVT-GR-SPORT-AT-2021-4228
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-CVT-GR-SPORT-AT-2021-4058
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-TRD-(ALL-NEW)-AT-2020-4260
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-TRD-(ALL-NEW)-AT-2020-3907
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-LIMITED-(NEW)-AT-2012-3474
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-S-AT-LIMITED-(NEW)-AT-2012-4421
# https://toyotatrust.astra.co.id/TOYOTA-YARIS-YARIS-1.5-E-MT-(NEW)-MT-2013-4326
# https://toyotatrust.astra.co.id/TOYOTA-VOXY-2.0-AT-AT-2017-3067
# https://toyotatrust.astra.co.id/TOYOTA-RUSH-RUSH-1.5-S
# https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.4-AT-(ALL-NEW)-AT-2012-3232
# https://toyotatrust.astra.co.id/HONDA-CRV-CR-V-2.0-AT-(ALL-NEW)-AT-2014-4306
# https://toyotatrust.astra.co.id/HONDA-CRV-ALL-NEW-CRV-2.0-AT-AT-2017-2987
# https://toyotatrust.astra.co.id/HONDA-CRV-ALL-NEW-CRV-1.5-TURBO-PRESTIGE-AT-AT-2018-4584
# https://toyotatrust.astra.co.id/HONDA-CITY-CITY--IVTEC-1.5-E-CVT-(ALL-NEW)-AT-2019-4249
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-4341
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-3629
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-MT-MT-2017-4253
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-PRESTIGE-AT-2017-4670
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-AT-2019-4201
# https://toyotatrust.astra.co.id/HONDA-BRV-BR-V-E-AT-AT-2016-4511
# https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-SATYA-E-1.2-MT-MT-2017-4786
# https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-SATYA-E-1.2-MT-(ALL-NEW)-MT-2019-4314
# https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-MT-MT-2016-4060
# https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-MT-MT-2016-4157
# https://toyotatrust.astra.co.id/HONDA-BRIO-BRIO-RS-1.2-CVT-AT-2016-4435
# https://toyotatrust.astra.co.id/DAIHATSU-XENIA-ALL-NEW-XENIA-1.3-X-MT-MT-2013-4689
# https://toyotatrust.astra.co.id/DAIHATSU-AYLA-NEW-AYLA-1.2-R-AT-AT-2018-4783

# %%
# Create a DataFrame using the data collected
data = {'Product link': product_link,'Product name': product_name,'Product Model': product_model, 'Product Type': product_type,
        'Product price' : product_price,'Product police number': product_police_n,'Product police number type':product_police_n_t,
        'Product Mileage': product_mileage,'Production year' : production_year,'Product post location': product_post_location,
        'Product color' : product_color, 'Product fuel type': product_fuel_type,
         'Product Transmission': product_transmission}

# %%
output = pd.DataFrame(data)
output
# Out:
#                                           Product link  \
# 0    https://toyotatrust.astra.co.id/TOYOTA-YARIS-Y...
# 1    https://toyotatrust.astra.co.id/TOYOTA-YARIS-Y...
# 2    https://toyotatrust.astra.co.id/TOYOTA-YARIS-Y...
# 3    https://toyotatrust.astra.co.id/TOYOTA-YARIS-Y...
# 4    https://toyotatrust.astra.co.id/TOYOTA-YARIS-Y...
# ..                                                 ...
# 141  https://toyotatrust.astra.co.id/HONDA-BRIO-BRI...
# 142  https://toyotatrust.astra.co.id/HONDA-BRIO-BRI...
# 143  https://toyotatrust.astra.co.id/HONDA-BRIO-BRI...
# 144  https://toyotatrust.astra.co.id/DAIHATSU-XENIA...
# 145  https://toyotatrust.astra.co.id/DAIHATSU-AYLA-...
#
#                                           Product name Product Model  \
# 0    TOYOTA YARIS YARIS 1.5 S MT TRD (ALL NEW) MT 2021         YARIS
# 1    TOYOTA YARIS YARIS 1.5 S MT TRD (ALL NEW) MT 2020         YARIS
# 2    TOYOTA YARIS YARIS 1.5 S MT TRD (ALL NEW) MT 2019         YARIS
# 3        TOYOTA YARIS YARIS 1.5 S CVT GR SPORT AT 2021         YARIS
# 4        TOYOTA YARIS YARIS 1.5 S CVT GR SPORT AT 2021         YARIS
# ..                                                 ...           ...
# 141                  HONDA BRIO BRIO RS 1.2 MT MT 2016          BRIO
# 142                  HONDA BRIO BRIO RS 1.2 MT MT 2016          BRIO
# 143                 HONDA BRIO BRIO RS 1.2 CVT AT 2016          BRIO
# 144      DAIHATSU XENIA ALL NEW XENIA 1.3 X MT MT 2013         XENIA
# 145            DAIHATSU AYLA NEW AYLA 1.2 R AT AT 2018          AYLA
#
#                      Product Type   Product price Product police number  \
# 0    YARIS 1.5 S MT TRD (ALL NEW)  Rp 268.900.000             W 1455 BF
# 1    YARIS 1.5 S MT TRD (ALL NEW)  Rp 227.000.000           BK 1125 ABG
# 2    YARIS 1.5 S MT TRD (ALL NEW)  Rp 218.000.000            BK 1453 RT
# 3        YARIS 1.5 S CVT GR SPORT  Rp 280.000.000            B 2960 UZN
# 4        YARIS 1.5 S CVT GR SPORT  Rp 285.000.000            B 2454 FFX
# ..                            ...             ...                   ...
# 141                BRIO RS 1.2 MT  Rp 132.000.000            D 1336 UAG
# 142                BRIO RS 1.2 MT  Rp 125.000.000           BK 1096 LTA
# 143               BRIO RS 1.2 CVT  Rp 142.000.000            D 1815 UAG
# 144        ALL NEW XENIA 1.3 X MT  Rp 105.000.000             T 1385 AH
# 145             NEW AYLA 1.2 R AT  Rp 127.300.000            AG 1394 VX
#
#     Product police number type Product Mileage Production year  \
# 0                          odd            9613            2021
# 1                          odd           36235            2020
# 2                          odd           21460            2019
# 3                         even            9102            2021
# 4                         even           10634            2021
# ..                         ...             ...             ...
# 141                       even           73405            2016
# 142                       even           31688            2016
# 143                        odd           41482            2016
# 144                        odd           43095            2013
# 145                       even           77861            2018
#
#     Product post location Product color Product fuel type Product Transmission
# 0                Surabaya         WHITE          GASOLINE                   MT
# 1                   Medan         BLACK          GASOLINE                   MT
# 2                   Medan         BLACK          GASOLINE                   MT
# 3              Kalimalang        SILVER                                     AT
# 4              Kalimalang        YELLOW                                     AT
# ..                    ...           ...               ...                  ...
# 141                    SH           RED                                     MT
# 142                 Medan         WHITE          GASOLINE                   MT
# 143                    SH          GREY                                     AT
# 144              Karawang         BLACK          GASOLINE                   MT
# 145              Surabaya        ORANGE          GASOLINE                   AT
#
# [146 rows x 13 columns]

# %%
#export dataframe to csv
output.to_csv('ADAB _(72291)_(Wahyu_Maulana_Ziwangga)_autotrust_data_v3.csv', encoding='utf-8')
